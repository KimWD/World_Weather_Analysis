# %%
import random
import numpy as np
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ffad218efc3f56c20c9f18e980db1242

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lukulu
# Processing Record 2 of Set 1 | butembo
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | tura
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | yar-sale
# Processing Record 9 of Set 1 | tiksi
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | inta
# Processing Record 12 of Set 1 | deer lake
# Processing Record 13 of Set 1 | belaya gora
# Processing Record 14 of Set 1 | barstow
# Processing Record 15 of Set 1 | tasiilaq
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | laguna
# Processing Record 22 of Set 1 | sombreffe
# Processing Record 23 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | sambava
# Processing Record 26 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 1 | hasaki
# Processing Record 28 of Set 1 | esperance
# Processing Record 29 of Set 1 | boke
# Processing Record 30 of Set 1 | isiro
# Processing Record 31 of Set 1 | rodby
# Processing Record 32 of Set 1 | inisa
# Processing Record 33 of Set 1 | ruteng
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | chongqing
# Processing Record 36 of Set 1 | tuy hoa
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | dingzhou
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | yulara
# Processing Record 41 of Set 1 | constitucion
# Processing Record 42 of Set 1 | gold coast
# Processing Record 43 of Set 1 | namatanai
# Processing Record 44 of Set 1 | saint-philippe
# Processing Record 45 of Set 1 | coihaique
# Processing Record 46 of Set 1 | bani walid
# Processing Record 47 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 1 | batsfjord
# Processing Record 49 of Set 1 | caborca
# Processing Record 50 of Set 1 | fuerte
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | dunedin
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | te anau
# Processing Record 5 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | castro
# Processing Record 8 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 9 of Set 2 | dikson
# Processing Record 10 of Set 2 | poum
# Processing Record 11 of Set 2 | oistins
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | busselton
# Processing Record 14 of Set 2 | road town
# Processing Record 15 of Set 2 | rocky mountain house
# Processing Record 16 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 17 of Set 2 | georgetown
# Processing Record 18 of Set 2 | urubicha
# Processing Record 19 of Set 2 | zaysan
# Processing Record 20 of Set 2 | talnakh
# Processing Record 21 of Set 2 | caraballeda
# Processing Record 22 of Set 2 | ushuaia
# Processing Record 23 of Set 2 | comodoro rivadavia
# Processing Record 24 of Set 2 | mackay
# Processing Record 25 of Set 2 | wawa
# Processing Record 26 of Set 2 | kiruna
# Processing Record 27 of Set 2 | frederico westphalen
# Processing Record 28 of Set 2 | russell
# Processing Record 29 of Set 2 | komsomolskiy
# Processing Record 30 of Set 2 | inhambane
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | badah
# Processing Record 33 of Set 2 | faanui
# Processing Record 34 of Set 2 | valparaiso
# Processing Record 35 of Set 2 | butaritari
# Processing Record 36 of Set 2 | latung
# Processing Record 37 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 2 | bubaque
# Processing Record 39 of Set 2 | khatanga
# Processing Record 40 of Set 2 | barrow
# Processing Record 41 of Set 2 | luderitz
# Processing Record 42 of Set 2 | ocos
# Processing Record 43 of Set 2 | ust-shonosha
# Processing Record 44 of Set 2 | sfantu gheorghe
# Processing Record 45 of Set 2 | longyearbyen
# Processing Record 46 of Set 2 | biak
# Processing Record 47 of Set 2 | lata
# Processing Record 48 of Set 2 | souillac
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | jackson
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | aginskoye
# Processing Record 3 of Set 3 | corner brook
# Processing Record 4 of Set 3 | lokosovo
# Processing Record 5 of Set 3 | marsh harbour
# Processing Record 6 of Set 3 | cobh
# Processing Record 7 of Set 3 | haines junction
# Processing Record 8 of Set 3 | ballina
# Processing Record 9 of Set 3 | beloha
# Processing Record 10 of Set 3 | lind
# Processing Record 11 of Set 3 | salalah
# Processing Record 12 of Set 3 | paracuru
# Processing Record 13 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 3 | bathsheba
# Processing Record 15 of Set 3 | presidencia roque saenz pena
# Processing Record 16 of Set 3 | plast
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | piopio
# Processing Record 19 of Set 3 | san blas
# Processing Record 20 of Set 3 | hobart
# Processing Record 21 of Set 3 | thompson
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | vaini
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | norman wells
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | kieta
# Processing Record 28 of Set 3 | tuatapere
# Processing Record 29 of Set 3 | beboto
# Processing Record 30 of Set 3 | grand baie
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | fairbanks
# Processing Record 36 of Set 3 | palana
# Processing Record 37 of Set 3 | shwebo
# Processing Record 38 of Set 3 | codajas
# Processing Record 39 of Set 3 | edd
# Processing Record 40 of Set 3 | lodja
# Processing Record 41 of Set 3 | bengkulu
# Processing Record 42 of Set 3 | karratha
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | promissao
# Processing Record 45 of Set 3 | sandwick
# Processing Record 46 of Set 3 | svetlaya
# Processing Record 47 of Set 3 | padang
# Processing Record 48 of Set 3 | zanjan
# Processing Record 49 of Set 3 | port hardy
# Processing Record 50 of Set 3 | sao filipe
# Processing Record 1 of Set 4 | port shepstone
# Processing Record 2 of Set 4 | hami
# Processing Record 3 of Set 4 | bredasdorp
# Processing Record 4 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 5 of Set 4 | walvis bay
# Processing Record 6 of Set 4 | ilulissat
# Processing Record 7 of Set 4 | torbay
# Processing Record 8 of Set 4 | namibe
# Processing Record 9 of Set 4 | changli
# Processing Record 10 of Set 4 | bati
# Processing Record 11 of Set 4 | tiarei
# Processing Record 12 of Set 4 | oxford
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | san patricio
# Processing Record 15 of Set 4 | port keats
# Processing Record 16 of Set 4 | unity
# Processing Record 17 of Set 4 | kusti
# Processing Record 18 of Set 4 | ponta do sol
# Processing Record 19 of Set 4 | isangel
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | rolim de moura
# City not found. Skipping...
# Processing Record 22 of Set 4 | tadine
# Processing Record 23 of Set 4 | bilibino
# Processing Record 24 of Set 4 | cap malheureux
# Processing Record 25 of Set 4 | severo-kurilsk
# Processing Record 26 of Set 4 | hailar
# Processing Record 27 of Set 4 | ust-nera
# Processing Record 28 of Set 4 | virden
# Processing Record 29 of Set 4 | lagoa
# Processing Record 30 of Set 4 | verkhoyansk
# Processing Record 31 of Set 4 | tazmalt
# Processing Record 32 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 33 of Set 4 | yellowknife
# Processing Record 34 of Set 4 | marsa matruh
# Processing Record 35 of Set 4 | bethel
# Processing Record 36 of Set 4 | ulan-ude
# Processing Record 37 of Set 4 | burnie
# Processing Record 38 of Set 4 | clyde river
# Processing Record 39 of Set 4 | vao
# Processing Record 40 of Set 4 | bonavista
# Processing Record 41 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 4 | victoria
# Processing Record 43 of Set 4 | monrovia
# Processing Record 44 of Set 4 | fortuna
# Processing Record 45 of Set 4 | azul
# Processing Record 46 of Set 4 | melfi
# Processing Record 47 of Set 4 | port blair
# Processing Record 48 of Set 4 | san luis
# Processing Record 49 of Set 4 | borogontsy
# Processing Record 50 of Set 4 | new norfolk
# Processing Record 1 of Set 5 | pandan niog
# Processing Record 2 of Set 5 | lebyazhye
# Processing Record 3 of Set 5 | teguldet
# Processing Record 4 of Set 5 | san felipe
# Processing Record 5 of Set 5 | ribeira grande
# Processing Record 6 of Set 5 | touros
# Processing Record 7 of Set 5 | bluff
# Processing Record 8 of Set 5 | airai
# Processing Record 9 of Set 5 | cartagena
# Processing Record 10 of Set 5 | vangaindrano
# Processing Record 11 of Set 5 | broome
# Processing Record 12 of Set 5 | shelburne
# Processing Record 13 of Set 5 | teo
# Processing Record 14 of Set 5 | kaitangata
# Processing Record 15 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 5 | kodiak
# Processing Record 17 of Set 5 | alofi
# Processing Record 18 of Set 5 | yibin
# Processing Record 19 of Set 5 | burica
# City not found. Skipping...
# Processing Record 20 of Set 5 | saint-pierre
# Processing Record 21 of Set 5 | rawson
# Processing Record 22 of Set 5 | plettenberg bay
# Processing Record 23 of Set 5 | port macquarie
# Processing Record 24 of Set 5 | divinopolis
# Processing Record 25 of Set 5 | mount gambier
# Processing Record 26 of Set 5 | bac can
# City not found. Skipping...
# Processing Record 27 of Set 5 | meulaboh
# Processing Record 28 of Set 5 | nanortalik
# Processing Record 29 of Set 5 | luanda
# Processing Record 30 of Set 5 | boyolangu
# Processing Record 31 of Set 5 | sanary-sur-mer
# Processing Record 32 of Set 5 | oeiras do para
# Processing Record 33 of Set 5 | livingstone
# Processing Record 34 of Set 5 | tateyama
# Processing Record 35 of Set 5 | ancud
# Processing Record 36 of Set 5 | flinders
# Processing Record 37 of Set 5 | muret
# Processing Record 38 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 39 of Set 5 | cidreira
# Processing Record 40 of Set 5 | nieuwpoort
# Processing Record 41 of Set 5 | elizabeth city
# Processing Record 42 of Set 5 | balykshi
# Processing Record 43 of Set 5 | sechura
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | kahului
# Processing Record 46 of Set 5 | magadan
# Processing Record 47 of Set 5 | sobolevo
# Processing Record 48 of Set 5 | yambio
# Processing Record 49 of Set 5 | la romana
# Processing Record 50 of Set 5 | morlaix
# Processing Record 1 of Set 6 | misratah
# Processing Record 2 of Set 6 | pringsewu
# Processing Record 3 of Set 6 | tessalit
# Processing Record 4 of Set 6 | tambopata
# Processing Record 5 of Set 6 | port elizabeth
# Processing Record 6 of Set 6 | mollendo
# Processing Record 7 of Set 6 | geraldton
# Processing Record 8 of Set 6 | ixtapa
# Processing Record 9 of Set 6 | jacqueville
# Processing Record 10 of Set 6 | mashhad
# Processing Record 11 of Set 6 | meadow lake
# Processing Record 12 of Set 6 | iqaluit
# Processing Record 13 of Set 6 | jinchang
# Processing Record 14 of Set 6 | bhagwantnagar
# Processing Record 15 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 16 of Set 6 | asfi
# Processing Record 17 of Set 6 | baracoa
# Processing Record 18 of Set 6 | cumberland
# Processing Record 19 of Set 6 | thai binh
# Processing Record 20 of Set 6 | alihe
# Processing Record 21 of Set 6 | west bay
# Processing Record 22 of Set 6 | cururupu
# Processing Record 23 of Set 6 | kytlym
# City not found. Skipping...
# Processing Record 24 of Set 6 | kovdor
# Processing Record 25 of Set 6 | hambantota
# Processing Record 26 of Set 6 | whitehorse
# Processing Record 27 of Set 6 | praia da vitoria
# Processing Record 28 of Set 6 | lima
# Processing Record 29 of Set 6 | altay
# Processing Record 30 of Set 6 | sabang
# Processing Record 31 of Set 6 | monduli
# Processing Record 32 of Set 6 | east london
# Processing Record 33 of Set 6 | san cristobal
# Processing Record 34 of Set 6 | azanka
# Processing Record 35 of Set 6 | srednekolymsk
# Processing Record 36 of Set 6 | provideniya
# Processing Record 37 of Set 6 | sabha
# Processing Record 38 of Set 6 | westport
# Processing Record 39 of Set 6 | djibo
# Processing Record 40 of Set 6 | wagga wagga
# Processing Record 41 of Set 6 | balingasay
# Processing Record 42 of Set 6 | filottrano
# Processing Record 43 of Set 6 | kondinskoye
# Processing Record 44 of Set 6 | husavik
# Processing Record 45 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 6 | marienburg
# Processing Record 47 of Set 6 | adeje
# Processing Record 48 of Set 6 | baykit
# Processing Record 49 of Set 6 | bud
# Processing Record 50 of Set 6 | panlaitan
# Processing Record 1 of Set 7 | bandarbeyla
# Processing Record 2 of Set 7 | nanpiao
# Processing Record 3 of Set 7 | faya
# Processing Record 4 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 5 of Set 7 | hervey bay
# Processing Record 6 of Set 7 | mossendjo
# Processing Record 7 of Set 7 | abaetetuba
# Processing Record 8 of Set 7 | tazovskiy
# Processing Record 9 of Set 7 | fort nelson
# Processing Record 10 of Set 7 | karpathos
# Processing Record 11 of Set 7 | deputatskiy
# Processing Record 12 of Set 7 | ajdabiya
# Processing Record 13 of Set 7 | mapanas
# Processing Record 14 of Set 7 | neyshabur
# Processing Record 15 of Set 7 | los llanos de aridane
# Processing Record 16 of Set 7 | saint george
# Processing Record 17 of Set 7 | mongoumba
# Processing Record 18 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 7 | berlevag
# Processing Record 20 of Set 7 | barra
# Processing Record 21 of Set 7 | palu
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | verkhnevilyuysk
# Processing Record 24 of Set 7 | okahandja
# Processing Record 25 of Set 7 | porto novo
# Processing Record 26 of Set 7 | jalu
# Processing Record 27 of Set 7 | mahajanga
# Processing Record 28 of Set 7 | chuy
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | solnechnyy
# Processing Record 31 of Set 7 | villanueva
# Processing Record 32 of Set 7 | mecca
# Processing Record 33 of Set 7 | goderich
# Processing Record 34 of Set 7 | bambous virieux
# Processing Record 35 of Set 7 | margate
# Processing Record 36 of Set 7 | shimoda
# Processing Record 37 of Set 7 | montenegro
# Processing Record 38 of Set 7 | merauke
# Processing Record 39 of Set 7 | mosalsk
# Processing Record 40 of Set 7 | quesnel
# Processing Record 41 of Set 7 | mont-dore
# Processing Record 42 of Set 7 | vanimo
# Processing Record 43 of Set 7 | ostrovnoy
# Processing Record 44 of Set 7 | vardo
# Processing Record 45 of Set 7 | portland
# Processing Record 46 of Set 7 | cayenne
# Processing Record 47 of Set 7 | ulladulla
# Processing Record 48 of Set 7 | chapais
# Processing Record 49 of Set 7 | salina cruz
# Processing Record 50 of Set 7 | honningsvag
# Processing Record 1 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 2 of Set 8 | cabanas
# Processing Record 3 of Set 8 | pevek
# Processing Record 4 of Set 8 | urucara
# Processing Record 5 of Set 8 | pingzhuang
# Processing Record 6 of Set 8 | keti bandar
# Processing Record 7 of Set 8 | sitka
# Processing Record 8 of Set 8 | rocha
# Processing Record 9 of Set 8 | denpasar
# Processing Record 10 of Set 8 | amapa
# Processing Record 11 of Set 8 | lompoc
# Processing Record 12 of Set 8 | ormara
# Processing Record 13 of Set 8 | nevsehir
# Processing Record 14 of Set 8 | tongren
# Processing Record 15 of Set 8 | samarai
# Processing Record 16 of Set 8 | saint-augustin
# Processing Record 17 of Set 8 | mata
# Processing Record 18 of Set 8 | marawi
# Processing Record 19 of Set 8 | rengasdengklok
# Processing Record 20 of Set 8 | vestmannaeyjar
# Processing Record 21 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 22 of Set 8 | noumea
# Processing Record 23 of Set 8 | usinsk
# Processing Record 24 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 8 | ilo
# Processing Record 26 of Set 8 | hvide sande
# Processing Record 27 of Set 8 | barra do garcas
# Processing Record 28 of Set 8 | quatre cocos
# Processing Record 29 of Set 8 | bingol
# Processing Record 30 of Set 8 | methven
# Processing Record 31 of Set 8 | chipata
# Processing Record 32 of Set 8 | leh
# Processing Record 33 of Set 8 | montevideo
# Processing Record 34 of Set 8 | guaruja
# Processing Record 35 of Set 8 | bafia
# Processing Record 36 of Set 8 | olafsvik
# Processing Record 37 of Set 8 | shingu
# Processing Record 38 of Set 8 | kavaratti
# Processing Record 39 of Set 8 | bumba
# Processing Record 40 of Set 8 | acaponeta
# Processing Record 41 of Set 8 | tucumcari
# Processing Record 42 of Set 8 | hofn
# Processing Record 43 of Set 8 | fatehpur
# Processing Record 44 of Set 8 | wanning
# Processing Record 45 of Set 8 | nizhneudinsk
# Processing Record 46 of Set 8 | peruibe
# Processing Record 47 of Set 8 | quchan
# Processing Record 48 of Set 8 | codrington
# Processing Record 49 of Set 8 | saint-honore
# Processing Record 50 of Set 8 | tiznit
# Processing Record 1 of Set 9 | rundu
# Processing Record 2 of Set 9 | richards bay
# Processing Record 3 of Set 9 | billund
# Processing Record 4 of Set 9 | san estanislao
# Processing Record 5 of Set 9 | mandera
# Processing Record 6 of Set 9 | salme
# Processing Record 7 of Set 9 | honiara
# Processing Record 8 of Set 9 | laibin
# Processing Record 9 of Set 9 | lubango
# Processing Record 10 of Set 9 | necochea
# Processing Record 11 of Set 9 | ornskoldsvik
# Processing Record 12 of Set 9 | muros
# Processing Record 13 of Set 9 | cherskiy
# Processing Record 14 of Set 9 | morant bay
# Processing Record 15 of Set 9 | vila franca do campo
# Processing Record 16 of Set 9 | ongandjera
# Processing Record 17 of Set 9 | dabat
# Processing Record 18 of Set 9 | evensk
# Processing Record 19 of Set 9 | acapulco
# Processing Record 20 of Set 9 | prabumulih
# Processing Record 21 of Set 9 | mubende
# Processing Record 22 of Set 9 | kamaishi
# Processing Record 23 of Set 9 | svetlyy
# Processing Record 24 of Set 9 | rumoi
# Processing Record 25 of Set 9 | kimry
# Processing Record 26 of Set 9 | sioux lookout
# Processing Record 27 of Set 9 | sao joao da barra
# Processing Record 28 of Set 9 | dehloran
# Processing Record 29 of Set 9 | pochutla
# Processing Record 30 of Set 9 | pacific grove
# Processing Record 31 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 9 | talara
# Processing Record 33 of Set 9 | cowra
# Processing Record 34 of Set 9 | sistranda
# Processing Record 35 of Set 9 | timra
# Processing Record 36 of Set 9 | kudahuvadhoo
# Processing Record 37 of Set 9 | narrabri
# Processing Record 38 of Set 9 | stromness
# Processing Record 39 of Set 9 | baglung
# Processing Record 40 of Set 9 | erenhot
# Processing Record 41 of Set 9 | mansa
# Processing Record 42 of Set 9 | andenes
# Processing Record 43 of Set 9 | ust-tsilma
# Processing Record 44 of Set 9 | kavieng
# Processing Record 45 of Set 9 | atar
# Processing Record 46 of Set 9 | maniwaki
# Processing Record 47 of Set 9 | kasongo-lunda
# Processing Record 48 of Set 9 | mantua
# Processing Record 49 of Set 9 | broken hill
# Processing Record 50 of Set 9 | saldanha
# Processing Record 1 of Set 10 | aklavik
# Processing Record 2 of Set 10 | wuzhou
# Processing Record 3 of Set 10 | guerrero negro
# Processing Record 4 of Set 10 | stornoway
# Processing Record 5 of Set 10 | ukiah
# Processing Record 6 of Set 10 | egvekinot
# Processing Record 7 of Set 10 | san juan
# Processing Record 8 of Set 10 | laela
# Processing Record 9 of Set 10 | rio gallegos
# Processing Record 10 of Set 10 | abu zabad
# Processing Record 11 of Set 10 | sorong
# Processing Record 12 of Set 10 | port lincoln
# Processing Record 13 of Set 10 | wasilla
# Processing Record 14 of Set 10 | gualaquiza
# Processing Record 15 of Set 10 | mancio lima
# Processing Record 16 of Set 10 | uray
# Processing Record 17 of Set 10 | partizanskoye
# Processing Record 18 of Set 10 | valentin gomez farias
# Processing Record 19 of Set 10 | rio grande
# Processing Record 20 of Set 10 | karatau
# Processing Record 21 of Set 10 | dingle
# Processing Record 22 of Set 10 | sur
# Processing Record 23 of Set 10 | liku
# Processing Record 24 of Set 10 | oranjemund
# Processing Record 25 of Set 10 | piacabucu
# Processing Record 26 of Set 10 | santa isabel
# Processing Record 27 of Set 10 | bogorodskoye
# Processing Record 28 of Set 10 | katsuura
# Processing Record 29 of Set 10 | vostok
# Processing Record 30 of Set 10 | tecoanapa
# Processing Record 31 of Set 10 | mumford
# Processing Record 32 of Set 10 | clinton
# Processing Record 33 of Set 10 | muswellbrook
# Processing Record 34 of Set 10 | taburao
# City not found. Skipping...
# Processing Record 35 of Set 10 | inuvik
# Processing Record 36 of Set 10 | haifa
# Processing Record 37 of Set 10 | genoa
# Processing Record 38 of Set 10 | west wendover
# Processing Record 39 of Set 10 | matara
# Processing Record 40 of Set 10 | calabozo
# Processing Record 41 of Set 10 | woodward
# Processing Record 42 of Set 10 | kamenka
# Processing Record 43 of Set 10 | mikuni
# Processing Record 44 of Set 10 | maposeni
# Processing Record 45 of Set 10 | torrox
# Processing Record 46 of Set 10 | meridian
# Processing Record 47 of Set 10 | magaria
# Processing Record 48 of Set 10 | alta floresta
# Processing Record 49 of Set 10 | isla mujeres
# Processing Record 50 of Set 10 | severomuysk
# Processing Record 1 of Set 11 | solsvik
# City not found. Skipping...
# Processing Record 2 of Set 11 | vanavara
# Processing Record 3 of Set 11 | tamboril
# Processing Record 4 of Set 11 | pyapon
# Processing Record 5 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 6 of Set 11 | lunino
# Processing Record 7 of Set 11 | cockburn town
# Processing Record 8 of Set 11 | ust-ilimsk
# Processing Record 9 of Set 11 | jurm
# Processing Record 10 of Set 11 | colon
# Processing Record 11 of Set 11 | nouakchott
# Processing Record 12 of Set 11 | agadir
# Processing Record 13 of Set 11 | izhmorskiy
# Processing Record 14 of Set 11 | tromso
# Processing Record 15 of Set 11 | ponta delgada
# Processing Record 16 of Set 11 | verkhnyaya inta
# Processing Record 17 of Set 11 | maldonado
# Processing Record 18 of Set 11 | sal rei
# Processing Record 19 of Set 11 | narsaq
# Processing Record 20 of Set 11 | jaen
# Processing Record 21 of Set 11 | merrill
# Processing Record 22 of Set 11 | ambon
# Processing Record 23 of Set 11 | morondava
# Processing Record 24 of Set 11 | zabid
# Processing Record 25 of Set 11 | anshun
# Processing Record 26 of Set 11 | potiskum
# Processing Record 27 of Set 11 | champerico
# Processing Record 28 of Set 11 | havre-saint-pierre
# Processing Record 29 of Set 11 | bongandanga
# Processing Record 30 of Set 11 | daru
# Processing Record 31 of Set 11 | nichinan
# Processing Record 32 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 33 of Set 11 | abbeville
# Processing Record 34 of Set 11 | asau
# Processing Record 35 of Set 11 | okhotsk
# Processing Record 36 of Set 11 | makakilo city
# Processing Record 37 of Set 11 | ketchikan
# Processing Record 38 of Set 11 | rudbar
# Processing Record 39 of Set 11 | maragogi
# Processing Record 40 of Set 11 | auki
# Processing Record 41 of Set 11 | san quintin
# Processing Record 42 of Set 11 | kaka
# Processing Record 43 of Set 11 | itarema
# Processing Record 44 of Set 11 | biloela
# Processing Record 45 of Set 11 | xichang
# Processing Record 46 of Set 11 | tsumeb
# Processing Record 47 of Set 11 | akdepe
# Processing Record 48 of Set 11 | dabola
# Processing Record 49 of Set 11 | sergeyevka
# Processing Record 50 of Set 11 | saint-ambroise
# Processing Record 1 of Set 12 | panaba
# Processing Record 2 of Set 12 | nabire
# Processing Record 3 of Set 12 | medicine hat
# Processing Record 4 of Set 12 | dabakala
# Processing Record 5 of Set 12 | mizan teferi
# Processing Record 6 of Set 12 | marrakesh
# Processing Record 7 of Set 12 | naze
# Processing Record 8 of Set 12 | kamyshla
# Processing Record 9 of Set 12 | san rafael del sur
# Processing Record 10 of Set 12 | lusaka
# Processing Record 11 of Set 12 | banda aceh
# Processing Record 12 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 13 of Set 12 | emba
# Processing Record 14 of Set 12 | martapura
# Processing Record 15 of Set 12 | weligama
# Processing Record 16 of Set 12 | nueva gerona
# Processing Record 17 of Set 12 | syracuse
# Processing Record 18 of Set 12 | lichinga
# Processing Record 19 of Set 12 | paamiut
# Processing Record 20 of Set 12 | galveston
# Processing Record 21 of Set 12 | celestun
# Processing Record 22 of Set 12 | bheramara
# Processing Record 23 of Set 12 | itoman
# Processing Record 24 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 25 of Set 12 | novopavlovka
# Processing Record 26 of Set 12 | san policarpo
# Processing Record 27 of Set 12 | goroka
# Processing Record 28 of Set 12 | pokrovsk
# Processing Record 29 of Set 12 | bronnoysund
# Processing Record 30 of Set 12 | soc trang
# Processing Record 31 of Set 12 | churapcha
# Processing Record 32 of Set 12 | takoradi
# Processing Record 33 of Set 12 | manuk mangkaw
# Processing Record 34 of Set 12 | hay river
# Processing Record 35 of Set 12 | wolomin
# Processing Record 36 of Set 12 | houma
# Processing Record 37 of Set 12 | muromtsevo
# Processing Record 38 of Set 12 | dargaville
# Processing Record 39 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 12 | general pico
# Processing Record 41 of Set 12 | maltahohe
# Processing Record 42 of Set 12 | dalvik
# Processing Record 43 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 44 of Set 12 | ferme-neuve
# Processing Record 45 of Set 12 | vila velha
# Processing Record 46 of Set 12 | kloulklubed
# Processing Record 47 of Set 12 | bambanglipuro
# Processing Record 48 of Set 12 | klaksvik
# Processing Record 49 of Set 12 | ouesso
# Processing Record 50 of Set 12 | doha
# Processing Record 1 of Set 13 | tabou
# Processing Record 2 of Set 13 | mount isa
# Processing Record 3 of Set 13 | mindelo
# Processing Record 4 of Set 13 | najran
# Processing Record 5 of Set 13 | leshukonskoye
# Processing Record 6 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 13 | kaduqli
# Processing Record 8 of Set 13 | port hedland
# Processing Record 9 of Set 13 | kruisfontein
# Processing Record 10 of Set 13 | santiago del estero
# Processing Record 11 of Set 13 | pahalgam
# Processing Record 12 of Set 13 | lorengau
# Processing Record 13 of Set 13 | ossora
# Processing Record 14 of Set 13 | scarborough
# Processing Record 15 of Set 13 | vigrestad
# Processing Record 16 of Set 13 | chumikan
# Processing Record 17 of Set 13 | ayorou
# Processing Record 18 of Set 13 | vermilion
# Processing Record 19 of Set 13 | kikwit
# Processing Record 20 of Set 13 | puerto escondido
# Processing Record 21 of Set 13 | buala
# Processing Record 22 of Set 13 | porgera
# Processing Record 23 of Set 13 | anloga
# Processing Record 24 of Set 13 | havoysund
# Processing Record 25 of Set 13 | luang prabang
# Processing Record 26 of Set 13 | harper
# Processing Record 27 of Set 13 | pangnirtung
# Processing Record 28 of Set 13 | aykhal
# Processing Record 29 of Set 13 | maniitsoq
# Processing Record 30 of Set 13 | galesong
# Processing Record 31 of Set 13 | bontang
# Processing Record 32 of Set 13 | bodden town
# Processing Record 33 of Set 13 | malanje
# Processing Record 34 of Set 13 | chulumani
# Processing Record 35 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 36 of Set 13 | murgab
# Processing Record 37 of Set 13 | alma
# Processing Record 38 of Set 13 | nuuk
# Processing Record 39 of Set 13 | atambua
# Processing Record 40 of Set 13 | shimoni
# Processing Record 41 of Set 13 | fenoarivo
# Processing Record 42 of Set 13 | peru
# Processing Record 43 of Set 13 | nouadhibou
# Processing Record 44 of Set 13 | batagay-alyta
# Processing Record 45 of Set 13 | beringovskiy
# Processing Record 46 of Set 13 | farmington
# Processing Record 47 of Set 13 | jiroft
# City not found. Skipping...
# Processing Record 48 of Set 13 | rio brilhante
# Processing Record 49 of Set 13 | lavumisa
# Processing Record 50 of Set 13 | chulym
# Processing Record 1 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 14 | goundam
# Processing Record 3 of Set 14 | sinnamary
# Processing Record 4 of Set 14 | chapada dos guimaraes
# Processing Record 5 of Set 14 | bollnas
# Processing Record 6 of Set 14 | tommot
# Processing Record 7 of Set 14 | abalak
# Processing Record 8 of Set 14 | yumen
# Processing Record 9 of Set 14 | matagami
# Processing Record 10 of Set 14 | catamarca
# Processing Record 11 of Set 14 | port pirie
# Processing Record 12 of Set 14 | puerto del rosario
# Processing Record 13 of Set 14 | cairns
# Processing Record 14 of Set 14 | natal
# Processing Record 15 of Set 14 | kralendijk
# Processing Record 16 of Set 14 | caiaponia
# Processing Record 17 of Set 14 | benghazi
# Processing Record 18 of Set 14 | hobyo
# Processing Record 19 of Set 14 | keflavik
# Processing Record 20 of Set 14 | artigas
# Processing Record 21 of Set 14 | boa vista
# Processing Record 22 of Set 14 | moose factory
# Processing Record 23 of Set 14 | vikulovo
# Processing Record 24 of Set 14 | kazachinskoye
# Processing Record 25 of Set 14 | kozan
# Processing Record 26 of Set 14 | manadhoo
# Processing Record 27 of Set 14 | ankara
# Processing Record 28 of Set 14 | flin flon
# Processing Record 29 of Set 14 | ambovombe
# Processing Record 30 of Set 14 | mahina
# Processing Record 31 of Set 14 | belyy yar
# Processing Record 32 of Set 14 | wajima
# Processing Record 33 of Set 14 | emerald
# Processing Record 34 of Set 14 | jardim
# Processing Record 35 of Set 14 | mapiripan
# Processing Record 36 of Set 14 | yunjinghong
# City not found. Skipping...
# Processing Record 37 of Set 14 | alpena
# Processing Record 38 of Set 14 | ilka
# City not found. Skipping...
# Processing Record 39 of Set 14 | sakakah
# Processing Record 40 of Set 14 | ucluelet
# Processing Record 41 of Set 14 | cabra
# Processing Record 42 of Set 14 | bo phloi
# Processing Record 43 of Set 14 | palauig
# Processing Record 44 of Set 14 | katsina
# Processing Record 45 of Set 14 | schaffhausen
# Processing Record 46 of Set 14 | batagay
# Processing Record 47 of Set 14 | jiwani
# Processing Record 48 of Set 14 | uglovskoye
# Processing Record 49 of Set 14 | lamu
# Processing Record 50 of Set 14 | bam
# Processing Record 1 of Set 15 | basco
# Processing Record 2 of Set 15 | labrea
# Processing Record 3 of Set 15 | caravelas
# Processing Record 4 of Set 15 | iralaya
# Processing Record 5 of Set 15 | mosquera
# Processing Record 6 of Set 15 | oussouye
# Processing Record 7 of Set 15 | carmarthen
# Processing Record 8 of Set 15 | manokwari
# Processing Record 9 of Set 15 | fougamou
# Processing Record 10 of Set 15 | gawler
# Processing Record 11 of Set 15 | gao
# Processing Record 12 of Set 15 | kirensk
# Processing Record 13 of Set 15 | eyl
# Processing Record 14 of Set 15 | millinocket
# Processing Record 15 of Set 15 | sadiqabad
# Processing Record 16 of Set 15 | hanting
# Processing Record 17 of Set 15 | karasuk
# Processing Record 18 of Set 15 | ahipara
# Processing Record 19 of Set 15 | half moon bay
# Processing Record 20 of Set 15 | mount darwin
# Processing Record 21 of Set 15 | springbok
# Processing Record 22 of Set 15 | suez
# Processing Record 23 of Set 15 | mazamari
# Processing Record 24 of Set 15 | laukaa
# Processing Record 25 of Set 15 | mengcheng
# Processing Record 26 of Set 15 | kysyl-syr
# Processing Record 27 of Set 15 | roma
# Processing Record 28 of Set 15 | jumla
# Processing Record 29 of Set 15 | grand gaube
# Processing Record 30 of Set 15 | wajir
# Processing Record 31 of Set 15 | vysokogornyy
# Processing Record 32 of Set 15 | namwala
# Processing Record 33 of Set 15 | ulaanbaatar
# Processing Record 34 of Set 15 | manggar
# Processing Record 35 of Set 15 | jiexiu
# Processing Record 36 of Set 15 | banjar
# Processing Record 37 of Set 15 | riviere-au-renard
# Processing Record 38 of Set 15 | we
# City not found. Skipping...
# Processing Record 39 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 15 | liezen
# Processing Record 41 of Set 15 | mama
# Processing Record 42 of Set 15 | hamilton
# Processing Record 43 of Set 15 | kalnciems
# Processing Record 44 of Set 15 | marathon
# Processing Record 45 of Set 15 | mangrol
# Processing Record 46 of Set 15 | labuhan
# Processing Record 47 of Set 15 | bayan
# Processing Record 48 of Set 15 | nhulunbuy
# Processing Record 49 of Set 15 | korba
# Processing Record 50 of Set 15 | mokshan
# Processing Record 1 of Set 16 | aurad
# Processing Record 2 of Set 16 | yerbogachen
# Processing Record 3 of Set 16 | gat
# Processing Record 4 of Set 16 | de aar
# Processing Record 5 of Set 16 | kushima
# Processing Record 6 of Set 16 | albanel
# Processing Record 7 of Set 16 | akyab
# Processing Record 8 of Set 16 | prainha
# Processing Record 9 of Set 16 | watertown
# Processing Record 10 of Set 16 | hovd
# Processing Record 11 of Set 16 | severo-yeniseyskiy
# Processing Record 12 of Set 16 | kerki
# City not found. Skipping...
# Processing Record 13 of Set 16 | bira
# Processing Record 14 of Set 16 | sucre
# Processing Record 15 of Set 16 | buenos aires
# Processing Record 16 of Set 16 | kati
# Processing Record 17 of Set 16 | tefe
# Processing Record 18 of Set 16 | sao miguel do araguaia
# Processing Record 19 of Set 16 | ingham
# Processing Record 20 of Set 16 | marondera
# Processing Record 21 of Set 16 | fethiye
# Processing Record 22 of Set 16 | sumbe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 724

# %%
# Create a city dataframe.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Lukulu      ZM -14.3707   23.2420     70.25        65          65
# 1   Butembo      CD   0.1500   29.2833     59.00        99          90
# 2   Mataura      NZ -46.1927  168.8643     50.49        84          13
# 3    Albany      US  42.6001  -73.9662     66.24        34         100
# 4    Avarua      CK -21.2078 -159.7750     71.65       100          85
# 5      Tura      IN  25.5198   90.2201     75.07        53           0
# 6   Rikitea      PF -23.1203 -134.9692     75.33        78         100
# 7  Yar-Sale      RU  66.8333   70.8333     15.55        95          54
# 8     Tiksi      RU  71.6872  128.8694     -6.23       100          98
# 9      Hilo      US  19.7297 -155.0900     72.28        93          75
#
#    Wind Speed Current Description
# 0        4.38       broken clouds
# 1        1.43          light rain
# 2        6.11          few clouds
# 3        5.99     overcast clouds
# 4        3.44     overcast clouds
# 5        5.70           clear sky
# 6       12.03     overcast clouds
# 7        7.76       broken clouds
# 8        3.13     overcast clouds
# 9        4.61       broken clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
